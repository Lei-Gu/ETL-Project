# %%
import pandas as pd
from sqlalchemy import create_engine

# %% [markdown]
# ### Extract CSVs into DataFrames

# %%
inspections = "Resources/food-inspections.csv"

# %%
licenses = "Resources/business-licenses.csv"

# %%
owners = "Resources/business-owners.csv"

# %% [markdown]
# ### Transform inspections DataFrame

# %%
inspections_df = pd.read_csv(inspections)
inspections_df.head()
# Out:
#    Inspection ID                                 DBA Name  \
# 0        2352683                   CHIPOTLE MEXICAN GRILL
# 1        2352734                              CHILI'S T-I
# 2        2352713  NICK'S FIRE GRILL STEAK & LEMONADE INC.
# 3        2352701                  TAQUERIA BLUE LINE INC.
# 4        2352727                 PORTAGE PARK DAY NURSERY
#
#                                   AKA Name  License #  \
# 0                   CHIPOTLE MEXICAN GRILL  2670642.0
# 1                         CHILI'S (T1-B14)    34169.0
# 2  NICK'S FIRE GRILL STEAK & LEMONADE INC.  2699090.0
# 3                                      NaN  2703436.0
# 4           MOSAIC EARLY CHILDHOOD ACADEMY  2215815.0
#
#                   Facility Type           Risk                  Address  \
# 0                    Restaurant  Risk 1 (High)       1025 W ADDISON ST
# 1                    Restaurant  Risk 1 (High)       11601 W TOUHY AVE
# 2                           NaN  Risk 1 (High)          2900 W 63RD ST
# 3                    Restaurant  Risk 1 (High)      3401 W BELMONT AVE
# 4  Children's Services Facility  Risk 1 (High)  5332-5334 W ADDISON ST
#
#       City State      Zip  ...             Results  \
# 0  CHICAGO    IL  60613.0  ...  Pass w/ Conditions
# 1  CHICAGO    IL  60666.0  ...                Pass
# 2  CHICAGO    IL  60629.0  ...           Not Ready
# 3  CHICAGO    IL  60618.0  ...  Pass w/ Conditions
# 4  CHICAGO    IL  60641.0  ...                Pass
#
#                                           Violations   Latitude  Longitude  \
# 0  3. MANAGEMENT, FOOD EMPLOYEE AND CONDITIONAL E...  41.947118 -87.655381
# 1  10. ADEQUATE HANDWASHING SINKS PROPERLY SUPPLI...  42.008536 -87.914428
# 2                                                NaN  41.779190 -87.695892
# 3  3. MANAGEMENT, FOOD EMPLOYEE AND CONDITIONAL E...  41.939168 -87.712546
# 4                                                NaN  41.946065 -87.760722
#
#                                             Location  \
# 0  {'latitude': '-87.6553811622124', 'longitude':...
# 1  {'latitude': '-87.91442843927047', 'longitude'...
# 2  {'latitude': '-87.69589237398256', 'longitude'...
# 3  {'latitude': '-87.71254599117191', 'longitude'...
# 4  {'latitude': '-87.76072227616888', 'longitude'...
#
#    Historical Wards 2003-2015 Zip Codes  Community Areas  Census Tracts  Wards
# 0                         NaN       NaN              NaN            NaN    NaN
# 1                         NaN       NaN              NaN            NaN    NaN
# 2                         NaN       NaN              NaN            NaN    NaN
# 3                         NaN       NaN              NaN            NaN    NaN
# 4                         NaN       NaN              NaN            NaN    NaN
#
# [5 rows x 22 columns]

# %%
new_inspections_df = inspections_df[['Inspection ID', 'License #', 'DBA Name','AKA Name','Risk','Inspection Date','Inspection Type','Results','Violations']].copy()
new_inspections_df.head()
# Out:
#    Inspection ID  License #                                 DBA Name  \
# 0        2352683  2670642.0                   CHIPOTLE MEXICAN GRILL
# 1        2352734    34169.0                              CHILI'S T-I
# 2        2352713  2699090.0  NICK'S FIRE GRILL STEAK & LEMONADE INC.
# 3        2352701  2703436.0                  TAQUERIA BLUE LINE INC.
# 4        2352727  2215815.0                 PORTAGE PARK DAY NURSERY
#
#                                   AKA Name           Risk  \
# 0                   CHIPOTLE MEXICAN GRILL  Risk 1 (High)
# 1                         CHILI'S (T1-B14)  Risk 1 (High)
# 2  NICK'S FIRE GRILL STEAK & LEMONADE INC.  Risk 1 (High)
# 3                                      NaN  Risk 1 (High)
# 4           MOSAIC EARLY CHILDHOOD ACADEMY  Risk 1 (High)
#
#            Inspection Date        Inspection Type             Results  \
# 0  2019-12-04T00:00:00.000  License Re-Inspection  Pass w/ Conditions
# 1  2019-12-04T00:00:00.000                Canvass                Pass
# 2  2019-12-04T00:00:00.000                License           Not Ready
# 3  2019-12-04T00:00:00.000                License  Pass w/ Conditions
# 4  2019-12-04T00:00:00.000                Canvass                Pass
#
#                                           Violations
# 0  3. MANAGEMENT, FOOD EMPLOYEE AND CONDITIONAL E...
# 1  10. ADEQUATE HANDWASHING SINKS PROPERLY SUPPLI...
# 2                                                NaN
# 3  3. MANAGEMENT, FOOD EMPLOYEE AND CONDITIONAL E...
# 4                                                NaN

# %% [markdown]
# ## Transform licenses DataFrame

# %%
licenses_df = pd.read_csv(licenses)
licenses_df.head()
# Out:
# C:\Users\Lance\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3058: DtypeWarning: Columns (9) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#              ID  LICENSE ID  ACCOUNT NUMBER  SITE NUMBER  \
# 0  101-20040516     1480073               1            1
# 1  101-20021116     1278029               1            1
# 2  101-20030516     1337924               1            1
# 3  100-20040516     1480076               1            1
# 4  101-20031116     1404362               1            1
#
#                                 LEGAL NAME DOING BUSINESS AS NAME  \
# 0  BERGHOFF RESTAURANT COMPANY OF DELAWARE  BERGHOFF'S RESTAURANT
# 1  BERGHOFF RESTAURANT COMPANY OF DELAWARE  BERGHOFF'S RESTAURANT
# 2  BERGHOFF RESTAURANT COMPANY OF DELAWARE  BERGHOFF'S RESTAURANT
# 3  BERGHOFF RESTAURANT COMPANY OF DELAWARE  BERGHOFF'S RESTAURANT
# 4  BERGHOFF RESTAURANT COMPANY OF DELAWARE  BERGHOFF'S RESTAURANT
#
#                ADDRESS     CITY STATE ZIP CODE  ...  \
# 0  17 W ADAMS ST # 1ST  CHICAGO    IL    60603  ...
# 1  17 W ADAMS ST # 1ST  CHICAGO    IL    60603  ...
# 2  17 W ADAMS ST # 1ST  CHICAGO    IL    60603  ...
# 3  17 W ADAMS ST # 1ST  CHICAGO    IL    60603  ...
# 4  17 W ADAMS ST # 1ST  CHICAGO    IL    60603  ...
#
#    LICENSE STATUS CHANGE DATE  SSA   LATITUDE  LONGITUDE  \
# 0                         NaN  1.0  41.879342 -87.628412
# 1                         NaN  1.0  41.879342 -87.628412
# 2                         NaN  1.0  41.879342 -87.628412
# 3                         NaN  1.0  41.879342 -87.628412
# 4                         NaN  1.0  41.879342 -87.628412
#
#                                             LOCATION Community Areas  \
# 0  {'latitude': '41.879341938770445', 'longitude'...            38.0
# 1  {'latitude': '41.879341938770445', 'longitude'...            38.0
# 2  {'latitude': '41.879341938770445', 'longitude'...            38.0
# 3  {'latitude': '41.879341938770445', 'longitude'...            38.0
# 4  {'latitude': '41.879341938770445', 'longitude'...            38.0
#
#   Historical Wards 2003-2015 Zip Codes  Census Tracts Wards
# 0                       22.0   14912.0           92.0  36.0
# 1                       22.0   14912.0           92.0  36.0
# 2                       22.0   14912.0           92.0  36.0
# 3                       22.0   14912.0           92.0  36.0
# 4                       22.0   14912.0           92.0  36.0
#
# [5 rows x 39 columns]

# %%
new_licenses = licenses_df[
    ['ID','LICENSE ID','ACCOUNT NUMBER','LEGAL NAME','DOING BUSINESS AS NAME','ADDRESS','CITY','STATE','ZIP CODE','LICENSE CODE','LICENSE DESCRIPTION','LICENSE TERM START DATE','LICENSE TERM EXPIRATION DATE','LICENSE STATUS','LATITUDE','LONGITUDE']].copy()
new_licenses.head()
# Out:
#              ID  LICENSE ID  ACCOUNT NUMBER  \
# 0  101-20040516     1480073               1
# 1  101-20021116     1278029               1
# 2  101-20030516     1337924               1
# 3  100-20040516     1480076               1
# 4  101-20031116     1404362               1
#
#                                 LEGAL NAME DOING BUSINESS AS NAME  \
# 0  BERGHOFF RESTAURANT COMPANY OF DELAWARE  BERGHOFF'S RESTAURANT
# 1  BERGHOFF RESTAURANT COMPANY OF DELAWARE  BERGHOFF'S RESTAURANT
# 2  BERGHOFF RESTAURANT COMPANY OF DELAWARE  BERGHOFF'S RESTAURANT
# 3  BERGHOFF RESTAURANT COMPANY OF DELAWARE  BERGHOFF'S RESTAURANT
# 4  BERGHOFF RESTAURANT COMPANY OF DELAWARE  BERGHOFF'S RESTAURANT
#
#                ADDRESS     CITY STATE ZIP CODE  LICENSE CODE  \
# 0  17 W ADAMS ST # 1ST  CHICAGO    IL    60603          1475
# 1  17 W ADAMS ST # 1ST  CHICAGO    IL    60603          1475
# 2  17 W ADAMS ST # 1ST  CHICAGO    IL    60603          1475
# 3  17 W ADAMS ST # 1ST  CHICAGO    IL    60603          1006
# 4  17 W ADAMS ST # 1ST  CHICAGO    IL    60603          1475
#
#                              LICENSE DESCRIPTION  LICENSE TERM START DATE  \
# 0  Consumption on Premises - Incidental Activity  2004-05-16T00:00:00.000
# 1  Consumption on Premises - Incidental Activity  2002-11-16T00:00:00.000
# 2  Consumption on Premises - Incidental Activity  2003-05-16T00:00:00.000
# 3                      Retail Food Establishment  2004-05-16T00:00:00.000
# 4  Consumption on Premises - Incidental Activity  2003-11-16T00:00:00.000
#
#   LICENSE TERM EXPIRATION DATE LICENSE STATUS   LATITUDE  LONGITUDE
# 0      2005-05-15T00:00:00.000            AAI  41.879342 -87.628412
# 1      2003-05-15T00:00:00.000            AAI  41.879342 -87.628412
# 2      2003-11-15T00:00:00.000            AAI  41.879342 -87.628412
# 3      2005-05-15T00:00:00.000            AAI  41.879342 -87.628412
# 4      2004-05-15T00:00:00.000            AAI  41.879342 -87.628412

# %% [markdown]
# ### Transform owners DataFrame

# %%
owners_df = pd.read_csv(owners)
owners_df.head()
# Out:
#    Account Number                       Legal Name Owner First Name  \
# 0          373231         PROCURIA CONSULTING, LLC              GUY
# 1          203002        NONA LISA FLOWERS & GIFTS            NELCY
# 2          338012    HAROLDS II BAR AND GRILL INC.          GREGORY
# 3           55221   CHICAGO PROVINCE SOCIETY OF JE           GEORGE
# 4           41354  WORLDWIDE TRAVEL MANAGEMENT INC          ANTHONY
#
#   Owner Middle Initial Owner Last Name Suffix Legal Entity Owner  \
# 0              WILLIAM         SELLARS    NaN                NaN
# 1                  NaN         SANTANA    NaN                NaN
# 2                  NaN       EDINGBURG    NaN                NaN
# 3                   A.            LANE    NaN                NaN
# 4                  NaN            VERA    NaN                NaN
#
#              Title
# 0  MANAGING MEMBER
# 1          PARTNER
# 2        SECRETARY
# 3        PRESIDENT
# 4        SECRETARY

# %%
new_owners_df = owners_df[
    ['Account Number','Legal Name','Owner First Name','Owner Last Name','Title']].copy()
new_owners_df.head()
# Out:
#    Account Number                       Legal Name Owner First Name  \
# 0          373231         PROCURIA CONSULTING, LLC              GUY
# 1          203002        NONA LISA FLOWERS & GIFTS            NELCY
# 2          338012    HAROLDS II BAR AND GRILL INC.          GREGORY
# 3           55221   CHICAGO PROVINCE SOCIETY OF JE           GEORGE
# 4           41354  WORLDWIDE TRAVEL MANAGEMENT INC          ANTHONY
#
#   Owner Last Name            Title
# 0         SELLARS  MANAGING MEMBER
# 1         SANTANA          PARTNER
# 2       EDINGBURG        SECRETARY
# 3            LANE        PRESIDENT
# 4            VERA        SECRETARY

# %% [markdown]
# ## Transformation

# %%
inspections_rename = new_inspections_df.rename(
    columns={'Inspection ID':'id', 'License #':'license_id', 'DBA Name':'dba_name','AKA Name':'aka_name','Risk':'risk','Inspection Date':'inspection_date','Inspection Type':'inspection_type','Results':'results','Violations':'violations'})

# %%
# inspections_rename.set_index("id", inplace =True)
inspections_rename.head()
# Out:
#         id  license_id                                 dba_name  \
# 0  2352683   2670642.0                   CHIPOTLE MEXICAN GRILL
# 1  2352734     34169.0                              CHILI'S T-I
# 2  2352713   2699090.0  NICK'S FIRE GRILL STEAK & LEMONADE INC.
# 3  2352701   2703436.0                  TAQUERIA BLUE LINE INC.
# 4  2352727   2215815.0                 PORTAGE PARK DAY NURSERY
#
#                                   aka_name           risk  \
# 0                   CHIPOTLE MEXICAN GRILL  Risk 1 (High)
# 1                         CHILI'S (T1-B14)  Risk 1 (High)
# 2  NICK'S FIRE GRILL STEAK & LEMONADE INC.  Risk 1 (High)
# 3                                      NaN  Risk 1 (High)
# 4           MOSAIC EARLY CHILDHOOD ACADEMY  Risk 1 (High)
#
#            inspection_date        inspection_type             results  \
# 0  2019-12-04T00:00:00.000  License Re-Inspection  Pass w/ Conditions
# 1  2019-12-04T00:00:00.000                Canvass                Pass
# 2  2019-12-04T00:00:00.000                License           Not Ready
# 3  2019-12-04T00:00:00.000                License  Pass w/ Conditions
# 4  2019-12-04T00:00:00.000                Canvass                Pass
#
#                                           violations
# 0  3. MANAGEMENT, FOOD EMPLOYEE AND CONDITIONAL E...
# 1  10. ADEQUATE HANDWASHING SINKS PROPERLY SUPPLI...
# 2                                                NaN
# 3  3. MANAGEMENT, FOOD EMPLOYEE AND CONDITIONAL E...
# 4                                                NaN

# %%
licenses_rename=new_licenses.rename(columns={
    'ID': 'id',
    'LICENSE ID':'license_id',
    'ACCOUNT NUMBER':'account_number',
    'LEGAL NAME':'legal_name',
    'DOING BUSINESS AS NAME':'business_name',
    'ADDRESS':'address',
    'CITY':'city',
    'STATE':'state',
    'ZIP CODE':'zip_code',
    'LICENSE CODE':'license_code',
    'LICENSE DESCRIPTION':'license_description',
    'LICENSE TERM START DATE':'license_start_date',
    'LICENSE TERM EXPIRATION DATE':'lincese_end_date',
    'LICENSE STATUS':'license_status',
    'LATITUDE':'latitude',
    'LONGITUDE':'longitude'
})

# %%
licenses_rename.set_index("id", inplace =False)
licenses_rename.head()
# Out:
#              id  license_id  account_number  \
# 0  101-20040516     1480073               1
# 1  101-20021116     1278029               1
# 2  101-20030516     1337924               1
# 3  100-20040516     1480076               1
# 4  101-20031116     1404362               1
#
#                                 legal_name          business_name  \
# 0  BERGHOFF RESTAURANT COMPANY OF DELAWARE  BERGHOFF'S RESTAURANT
# 1  BERGHOFF RESTAURANT COMPANY OF DELAWARE  BERGHOFF'S RESTAURANT
# 2  BERGHOFF RESTAURANT COMPANY OF DELAWARE  BERGHOFF'S RESTAURANT
# 3  BERGHOFF RESTAURANT COMPANY OF DELAWARE  BERGHOFF'S RESTAURANT
# 4  BERGHOFF RESTAURANT COMPANY OF DELAWARE  BERGHOFF'S RESTAURANT
#
#                address     city state zip_code  license_code  \
# 0  17 W ADAMS ST # 1ST  CHICAGO    IL    60603          1475
# 1  17 W ADAMS ST # 1ST  CHICAGO    IL    60603          1475
# 2  17 W ADAMS ST # 1ST  CHICAGO    IL    60603          1475
# 3  17 W ADAMS ST # 1ST  CHICAGO    IL    60603          1006
# 4  17 W ADAMS ST # 1ST  CHICAGO    IL    60603          1475
#
#                              license_description       license_start_date  \
# 0  Consumption on Premises - Incidental Activity  2004-05-16T00:00:00.000
# 1  Consumption on Premises - Incidental Activity  2002-11-16T00:00:00.000
# 2  Consumption on Premises - Incidental Activity  2003-05-16T00:00:00.000
# 3                      Retail Food Establishment  2004-05-16T00:00:00.000
# 4  Consumption on Premises - Incidental Activity  2003-11-16T00:00:00.000
#
#           lincese_end_date license_status   latitude  longitude
# 0  2005-05-15T00:00:00.000            AAI  41.879342 -87.628412
# 1  2003-05-15T00:00:00.000            AAI  41.879342 -87.628412
# 2  2003-11-15T00:00:00.000            AAI  41.879342 -87.628412
# 3  2005-05-15T00:00:00.000            AAI  41.879342 -87.628412
# 4  2004-05-15T00:00:00.000            AAI  41.879342 -87.628412

# %%
owners_rename=new_owners_df.rename(
    columns={
        'Account Number': 'account_number',
        'Legal Name': 'legal_name',
        'Owner First Name': 'owner_first_name',
        'Owner Last Name': 'owner_last_name',
        'Title': 'title'}
)
owners_rename.head()
# Out:
#    account_number                       legal_name owner_first_name  \
# 0          373231         PROCURIA CONSULTING, LLC              GUY
# 1          203002        NONA LISA FLOWERS & GIFTS            NELCY
# 2          338012    HAROLDS II BAR AND GRILL INC.          GREGORY
# 3           55221   CHICAGO PROVINCE SOCIETY OF JE           GEORGE
# 4           41354  WORLDWIDE TRAVEL MANAGEMENT INC          ANTHONY
#
#   owner_last_name            title
# 0         SELLARS  MANAGING MEMBER
# 1         SANTANA          PARTNER
# 2       EDINGBURG        SECRETARY
# 3            LANE        PRESIDENT
# 4            VERA        SECRETARY

# %% [markdown]
# # Cleaning data -Licenses

# %%
# check missing data
licenses_rename.count()
# Out:
# license_id             991117
# account_number         991117
# legal_name             991113
# business_name          991040
# address                991117
# city                   991114
# state                  991105
# zip_code               990693
# license_code           991117
# license_description    991117
# license_start_date     988431
# lincese_end_date       991022
# license_status         991117
# latitude               914138
# longitude              914138
# dtype: int64

# %%
# clean up the duplicate license ids if exist
licenses_cleaned = licenses_rename.dropna(subset=['license_id'])
licenses_cleaned.count()
# Out:
# id                     991117
# license_id             991117
# account_number         991117
# legal_name             991113
# business_name          991040
# address                991117
# city                   991114
# state                  991105
# zip_code               990693
# license_code           991117
# license_description    991117
# license_start_date     988431
# lincese_end_date       991022
# license_status         991117
# latitude               914138
# longitude              914138
# dtype: int64

# %%
# seclect city as Chicago
licenses_chicago =licenses_cleaned.loc[licenses_cleaned['city'] == 'CHICAGO']

licenses_chicago.count()
# Out:
# id                     918218
# license_id             918218
# account_number         918218
# legal_name             918218
# business_name          918198
# address                918218
# city                   918218
# state                  918206
# zip_code               917856
# license_code           918218
# license_description    918218
# license_start_date     915733
# lincese_end_date       918150
# license_status         918218
# latitude               910249
# longitude              910249
# dtype: int64

# %%
# Seperate the data into two dataframes

chicago_business_info = licenses_chicago[['account_number','legal_name','business_name','address','city','state','zip_code','latitude','longitude']].copy()
chicago_business_info.head()
# Out:
#    account_number                               legal_name  \
# 0               1  BERGHOFF RESTAURANT COMPANY OF DELAWARE
# 1               1  BERGHOFF RESTAURANT COMPANY OF DELAWARE
# 2               1  BERGHOFF RESTAURANT COMPANY OF DELAWARE
# 3               1  BERGHOFF RESTAURANT COMPANY OF DELAWARE
# 4               1  BERGHOFF RESTAURANT COMPANY OF DELAWARE
#
#            business_name              address     city state zip_code  \
# 0  BERGHOFF'S RESTAURANT  17 W ADAMS ST # 1ST  CHICAGO    IL    60603
# 1  BERGHOFF'S RESTAURANT  17 W ADAMS ST # 1ST  CHICAGO    IL    60603
# 2  BERGHOFF'S RESTAURANT  17 W ADAMS ST # 1ST  CHICAGO    IL    60603
# 3  BERGHOFF'S RESTAURANT  17 W ADAMS ST # 1ST  CHICAGO    IL    60603
# 4  BERGHOFF'S RESTAURANT  17 W ADAMS ST # 1ST  CHICAGO    IL    60603
#
#     latitude  longitude
# 0  41.879342 -87.628412
# 1  41.879342 -87.628412
# 2  41.879342 -87.628412
# 3  41.879342 -87.628412
# 4  41.879342 -87.628412

# %%
chicago_business_info.drop_duplicates(subset="account_number",inplace= True)

# %%
chicago_business_licenses = licenses_chicago[['license_id','account_number','license_code','license_description','license_start_date','lincese_end_date','license_status']].copy()
chicago_business_licenses.head()
# Out:
#    license_id  account_number  license_code  \
# 0     1480073               1          1475
# 1     1278029               1          1475
# 2     1337924               1          1475
# 3     1480076               1          1006
# 4     1404362               1          1475
#
#                              license_description       license_start_date  \
# 0  Consumption on Premises - Incidental Activity  2004-05-16T00:00:00.000
# 1  Consumption on Premises - Incidental Activity  2002-11-16T00:00:00.000
# 2  Consumption on Premises - Incidental Activity  2003-05-16T00:00:00.000
# 3                      Retail Food Establishment  2004-05-16T00:00:00.000
# 4  Consumption on Premises - Incidental Activity  2003-11-16T00:00:00.000
#
#           lincese_end_date license_status
# 0  2005-05-15T00:00:00.000            AAI
# 1  2003-05-15T00:00:00.000            AAI
# 2  2003-11-15T00:00:00.000            AAI
# 3  2005-05-15T00:00:00.000            AAI
# 4  2004-05-15T00:00:00.000            AAI

# %% [markdown]
# # Cleaning data -Inspections

# %%
# Transform Column "risk" from text to number
inspections_rename['risk'] = inspections_rename['risk'].astype(str).str.split().str[1]
inspections_rename.head()
# Out:
#         id  license_id                                 dba_name  \
# 0  2352683   2670642.0                   CHIPOTLE MEXICAN GRILL
# 1  2352734     34169.0                              CHILI'S T-I
# 2  2352713   2699090.0  NICK'S FIRE GRILL STEAK & LEMONADE INC.
# 3  2352701   2703436.0                  TAQUERIA BLUE LINE INC.
# 4  2352727   2215815.0                 PORTAGE PARK DAY NURSERY
#
#                                   aka_name risk          inspection_date  \
# 0                   CHIPOTLE MEXICAN GRILL    1  2019-12-04T00:00:00.000
# 1                         CHILI'S (T1-B14)    1  2019-12-04T00:00:00.000
# 2  NICK'S FIRE GRILL STEAK & LEMONADE INC.    1  2019-12-04T00:00:00.000
# 3                                      NaN    1  2019-12-04T00:00:00.000
# 4           MOSAIC EARLY CHILDHOOD ACADEMY    1  2019-12-04T00:00:00.000
#
#          inspection_type             results  \
# 0  License Re-Inspection  Pass w/ Conditions
# 1                Canvass                Pass
# 2                License           Not Ready
# 3                License  Pass w/ Conditions
# 4                Canvass                Pass
#
#                                           violations
# 0  3. MANAGEMENT, FOOD EMPLOYEE AND CONDITIONAL E...
# 1  10. ADEQUATE HANDWASHING SINKS PROPERLY SUPPLI...
# 2                                                NaN
# 3  3. MANAGEMENT, FOOD EMPLOYEE AND CONDITIONAL E...
# 4                                                NaN

# %% [markdown]
# ### Create database connection

# %%
username = "postgres"
password = "1988"
database = "Chicago Resturant Inspection"

rds_connection_string = f"{username}:{password}@localhost:5432/{database}"
engine = create_engine(f'postgresql://{rds_connection_string}')

# %%
# Confirm tables
engine.table_names()
# Out:
# ['licenses', 'inspections', 'businessinfo', 'owners', 'yelp']

# %% [markdown]
# ### Load DataFrames into database

# %%
chicago_business_licenses.to_sql(name='licenses', con=engine, if_exists='append', index=False)

# %%
chicago_business_info.to_sql(name='businessinfo', con=engine, if_exists='append', index=False)

# %%
inspections_rename.to_sql(name='inspections', con=engine, if_exists='append', index=False)
# Out:
# ---------------------------------------------------------------------------
# UniqueViolation                           Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1228                     self.dialect.do_executemany(
# -> 1229                         cursor, statement, parameters, context
#    1230                     )
#
# ~\Anaconda3\lib\site-packages\sqlalchemy\dialects\postgresql\psycopg2.py in do_executemany(self, cursor, statement, parameters, context)
#     853         if self.executemany_mode is EXECUTEMANY_DEFAULT:
# --> 854             cursor.executemany(statement, parameters)
#     855             return
#
# UniqueViolation: duplicate key value violates unique constraint "inspections_pkey"
# DETAIL:  Key (id)=(2286143) already exists.
#
#
# The above exception was the direct cause of the following exception:
#
# IntegrityError                            Traceback (most recent call last)
# <ipython-input-41-fd873a19f057> in <module>
# ----> 1 inspections_rename.to_sql(name='inspections', con=engine, if_exists='append', index=False)
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2710             chunksize=chunksize,
#    2711             dtype=dtype,
# -> 2712             method=method,
#    2713         )
#    2714
#
# ~\Anaconda3\lib\site-packages\pandas\io\sql.py in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#     516         chunksize=chunksize,
#     517         dtype=dtype,
# --> 518         method=method,
#     519     )
#     520
#
# ~\Anaconda3\lib\site-packages\pandas\io\sql.py in to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype, method)
#    1318         )
#    1319         table.create()
# -> 1320         table.insert(chunksize, method=method)
#    1321         if not name.isdigit() and not name.islower():
#    1322             # check for potentially case sensitivity issues (GH7815)
#
# ~\Anaconda3\lib\site-packages\pandas\io\sql.py in insert(self, chunksize, method)
#     754
#     755                 chunk_iter = zip(*[arr[start_i:end_i] for arr in data_list])
# --> 756                 exec_insert(conn, keys, chunk_iter)
#     757
#     758     def _query_iterator(
#
# ~\Anaconda3\lib\site-packages\pandas\io\sql.py in _execute_insert(self, conn, keys, data_iter)
#     668         """
#     669         data = [dict(zip(keys, row)) for row in data_iter]
# --> 670         conn.execute(self.table.insert(), data)
#     671
#     672     def _execute_insert_multi(self, conn, keys, data_iter):
#
# ~\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py in execute(self, object_, *multiparams, **params)
#     986             raise exc.ObjectNotExecutableError(object_)
#     987         else:
# --> 988             return meth(self, multiparams, params)
#     989
#     990     def _execute_function(self, func, multiparams, params):
#
# ~\Anaconda3\lib\site-packages\sqlalchemy\sql\elements.py in _execute_on_connection(self, connection, multiparams, params)
#     285     def _execute_on_connection(self, connection, multiparams, params):
#     286         if self.supports_execution:
# --> 287             return connection._execute_clauseelement(self, multiparams, params)
#     288         else:
#     289             raise exc.ObjectNotExecutableError(self)
#
# ~\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _execute_clauseelement(self, elem, multiparams, params)
#    1105             distilled_params,
#    1106             compiled_sql,
# -> 1107             distilled_params,
#    1108         )
#    1109         if self._has_events or self.engine._has_events:
#
# ~\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1251         except BaseException as e:
#    1252             self._handle_dbapi_exception(
# -> 1253                 e, statement, parameters, cursor, context
#    1254             )
#    1255
#
# ~\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _handle_dbapi_exception(self, e, statement, parameters, cursor, context)
#    1471                 util.raise_from_cause(newraise, exc_info)
#    1472             elif should_wrap:
# -> 1473                 util.raise_from_cause(sqlalchemy_exception, exc_info)
#    1474             else:
#    1475                 util.reraise(*exc_info)
#
# ~\Anaconda3\lib\site-packages\sqlalchemy\util\compat.py in raise_from_cause(exception, exc_info)
#     396     exc_type, exc_value, exc_tb = exc_info
#     397     cause = exc_value if exc_value is not exception else None
# --> 398     reraise(type(exception), exception, tb=exc_tb, cause=cause)
#     399
#     400
#
# ~\Anaconda3\lib\site-packages\sqlalchemy\util\compat.py in reraise(tp, value, tb, cause)
#     150             value.__cause__ = cause
#     151         if value.__traceback__ is not tb:
# --> 152             raise value.with_traceback(tb)
#     153         raise value
#     154
#
# ~\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1227                 if not evt_handled:
#    1228                     self.dialect.do_executemany(
# -> 1229                         cursor, statement, parameters, context
#    1230                     )
#    1231             elif not parameters and context.no_parameters:
#
# ~\Anaconda3\lib\site-packages\sqlalchemy\dialects\postgresql\psycopg2.py in do_executemany(self, cursor, statement, parameters, context)
#     852     def do_executemany(self, cursor, statement, parameters, context=None):
#     853         if self.executemany_mode is EXECUTEMANY_DEFAULT:
# --> 854             cursor.executemany(statement, parameters)
#     855             return
#     856
#
# IntegrityError: (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "inspections_pkey"
# DETAIL:  Key (id)=(2286143) already exists.
#
# [SQL: INSERT INTO inspections (id, license_id, dba_name, aka_name, risk, inspection_date, inspection_type, results, violations) VALUES (%(id)s, %(license_id)s, %(dba_name)s, %(aka_name)s, %(risk)s, %(inspection_date)s, %(inspection_type)s, %(results)s, %(violations)s)]
# [parameters: ({'id': 2352683, 'license_id': 2670642.0, 'dba_name': 'CHIPOTLE MEXICAN GRILL', 'aka_name': 'CHIPOTLE MEXICAN GRILL', 'risk': '1', 'inspection_date': '2019-12-04T00:00:00.000', 'inspection_type': 'License Re-Inspection', 'results': 'Pass w/ Conditions', 'violations': '3. MANAGEMENT, FOOD EMPLOYEE AND CONDITIONAL EMPLOYEE; KNOWLEDGE, RESPONSIBILITIES AND REPORTING - Comments: FOUND NO EMPLOYEE HEALTH POLICY AT PREMISES. PRIORITY FOUNDATION. NO CITATION ISSUED. 7-38-010. MUST PROVIDE.'}, {'id': 2352734, 'license_id': 34169.0, 'dba_name': "CHILI'S T-I", 'aka_name': "CHILI'S (T1-B14)", 'risk': '1', 'inspection_date': '2019-12-04T00:00:00.000', 'inspection_type': 'Canvass', 'results': 'Pass', 'violations': '10. ADEQUATE HANDWASHING SINKS PROPERLY SUPPLIED AND ACCESSIBLE - Comments: OBSERVED NO HAND WASHING SIGNAGE FOR HAND SINK AT REAR DISH WASHING AREA. ... (730 characters truncated) ... STALLED, MAINTAINED & CLEAN - Comments: OBSERVED DIRTY FLOORS UNDER AND AROUND THE ICE MACHINE SHOWED MANAGER,CLEAN FLOORS IN DETAIL AND TO MAINTAIN.'}, {'id': 2352713, 'license_id': 2699090.0, 'dba_name': "NICK'S FIRE GRILL STEAK & LEMONADE INC.", 'aka_name': "NICK'S FIRE GRILL STEAK & LEMONADE INC.", 'risk': '1', 'inspection_date': '2019-12-04T00:00:00.000', 'inspection_type': 'License', 'results': 'Not Ready', 'violations': None}, {'id': 2352701, 'license_id': 2703436.0, 'dba_name': 'TAQUERIA BLUE LINE INC.', 'aka_name': None, 'risk': '1', 'inspection_date': '2019-12-04T00:00:00.000', 'inspection_type': 'License', 'results': 'Pass w/ Conditions', 'violations': '3. MANAGEMENT, FOOD EMPLOYEE AND CONDITIONAL EMPLOYEE; KNOWLEDGE, RESPONSIBILITIES AND REPORTING - Comments: NO EMPLOYEE HEALTH POLICY ON PREMISES. I ... (980 characters truncated) ...  TRAINING CERTIFICATE ON PREMISES. INSTRUCTED ALL CITY OF CHICAGO CERTIFIED FOOD MANAGERS MUST HAVE FOOD ALLERGEN TRAINING  CERTIFICATES ON PREMISES.'}, {'id': 2352727, 'license_id': 2215815.0, 'dba_name': 'PORTAGE PARK DAY NURSERY', 'aka_name': 'MOSAIC EARLY CHILDHOOD ACADEMY', 'risk': '1', 'inspection_date': '2019-12-04T00:00:00.000', 'inspection_type': 'Canvass', 'results': 'Pass', 'violations': None}, {'id': 2352738, 'license_id': 1801618.0, 'dba_name': 'AMARIT RESTAURANT', 'aka_name': 'AMARIT RESTAURANT', 'risk': '1', 'inspection_date': '2019-12-04T00:00:00.000', 'inspection_type': 'Canvass Re-Inspection', 'results': 'Pass', 'violations': None}, {'id': 2352684, 'license_id': 2670643.0, 'dba_name': 'CHIPOTLE MEXICAN GRILL', 'aka_name': 'CHIPOTLE MEXICAN GRILL', 'risk': '1', 'inspection_date': '2019-12-04T00:00:00.000', 'inspection_type': 'License Re-Inspection', 'results': 'Pass w/ Conditions', 'violations': None}, {'id': 2352702, 'license_id': 2698776.0, 'dba_name': 'NAIBOA LATIN STORE', 'aka_name': 'NAIBOA LATIN STORE', 'risk': '3', 'inspection_date': '2019-12-04T00:00:00.000', 'inspection_type': 'License', 'results': 'Pass w/ Conditions', 'violations': '5. PROCEDURES FOR RESPONDING TO VOMITING AND DIARRHEAL EVENTS - Comments: MANAGEMENT UNABLE TO PROVIDE A PROCEDURE FOR CLEANING UP VOMITING AND DIARR ... (621 characters truncated) ...  WASH ROOMS ON PREMISE WITH GARBAGE RECEPTACLES AND NO LIDS. INSTRUCTED TO PROVIDE TRASH CANS WITH LIDS AT ALL WOMEN WASH ROOMS AND UNISEX WASH ROOMS'}  ... displaying 10 of 196825 total bound parameter sets ...  {'id': 70269, 'license_id': 1899292.0, 'dba_name': "mr.daniel's", 'aka_name': "mr.daniel's", 'risk': '1', 'inspection_date': '2010-01-04T00:00:00.000', 'inspection_type': 'License Re-Inspection', 'results': 'Pass', 'violations': None}, {'id': 67738, 'license_id': 2008948.0, 'dba_name': "MICHAEL'S ON MAIN CAFE", 'aka_name': "MICHAEL'S ON MAIN CAFE", 'risk': '1', 'inspection_date': '2010-01-04T00:00:00.000', 'inspection_type': 'License', 'results': 'Fail', 'violations': '18. NO EVIDENCE OF RODENT OR INSECT OUTER OPENINGS PROTECTED/RODENT PROOFED, A WRITTEN LOG SHALL BE MAINTAINED AVAILABLE TO THE INSPECTORS - Comments ... (582 characters truncated)  ...
# (Background on this error at: http://sqlalche.me/e/gkpj)

# %%
owners_rename.to_sql(name='owners', con=engine, if_exists='append', index=False)

# %%
pd.read_sql_query('select * from inspections', con=engine).head()
# Out:
#         id  license_no                                 dba_name  \
# 0  2352683   2670642.0                   CHIPOTLE MEXICAN GRILL
# 1  2352734     34169.0                              CHILI'S T-I
# 2  2352713   2699090.0  NICK'S FIRE GRILL STEAK & LEMONADE INC.
# 3  2352701   2703436.0                  TAQUERIA BLUE LINE INC.
# 4  2352727   2215815.0                 PORTAGE PARK DAY NURSERY
#
#                                   aka_name           risk  \
# 0                   CHIPOTLE MEXICAN GRILL  Risk 1 (High)
# 1                         CHILI'S (T1-B14)  Risk 1 (High)
# 2  NICK'S FIRE GRILL STEAK & LEMONADE INC.  Risk 1 (High)
# 3                                     None  Risk 1 (High)
# 4           MOSAIC EARLY CHILDHOOD ACADEMY  Risk 1 (High)
#
#            inspection_date        inspection_type             results  \
# 0  2019-12-04T00:00:00.000  License Re-Inspection  Pass w/ Conditions
# 1  2019-12-04T00:00:00.000                Canvass                Pass
# 2  2019-12-04T00:00:00.000                License           Not Ready
# 3  2019-12-04T00:00:00.000                License  Pass w/ Conditions
# 4  2019-12-04T00:00:00.000                Canvass                Pass
#
#                                           violations
# 0  3. MANAGEMENT, FOOD EMPLOYEE AND CONDITIONAL E...
# 1  10. ADEQUATE HANDWASHING SINKS PROPERLY SUPPLI...
# 2                                               None
# 3  3. MANAGEMENT, FOOD EMPLOYEE AND CONDITIONAL E...
# 4                                               None

# %%
county_df.to_sql(name='county', con=engine, if_exists='append', index=True)

# %%
pd.read_sql_query('select * from county', con=engine).head()
# Out:
#    id  county_name county_id license_count
# 0   0       ALBANY         5            77
# 1   1     ALLEGANY        59             4
# 2   2        BRONX         0           104
# 3   3       BROOME        35            14
# 4   4  CATTARAUGUS        41             9
