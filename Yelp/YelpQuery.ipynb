# %% [markdown]
# ## Yelp Rating Data Query
# * using gfairchild yelpai's implementation of Yelp Fusion API

# %% [markdown]
# ### Dependencies

# %%
## Import Dependencies
import pandas as pd
from yelpapi import YelpAPI

from config import api_key

# %%
## Yelp API
yelp_api = YelpAPI(api_key, timeout_s=2.0)

# %% [markdown]
# ### List of Businesses to Search in Yelp

# %%
# test data
inspection_data_path = "../Resources/TestData_Yelp.csv"
df = pd.read_csv(inspection_data_path)
df
# Out:
#     Inspection ID                      DBA Name                      AKA Name  \
# 0         2362315                      7-ELEVEN                      7-ELEVEN
# 1         2362304               MIDLANE ESPORTS               MIDLANE ESPORTS
# 2         2362343            EL MUCHACHO ALEGRE            EL MUCHACHO ALEGRE
# 3         2362312                      7-ELEVEN                      7-ELEVEN
# 4         2362297                     PORK CHOP                     PORK CHOP
# ..            ...                           ...                           ...
# 95        2360016            SARPINO'S PIZZERIA            SARPINO'S PIZZERIA
# 96        2359995    BRAZILIAN BOWL FRESH GRILL    BRAZILIAN BOWL FRESH GRILL
# 97        2360053        HOST INTERNATIONAL INC            STARBUCKS  (T3 H2)
# 98        2359975  EL FOGON DE ELENA RESTAURANT  EL FOGON DE ELENA RESTAURANT
# 99        2360033               EL CAMPESTRE #2               EL CAMPESTRE #2
#
#     License # Facility Type             Risk               Address     City  \
# 0     2704169    Restaurant  Risk 2 (Medium)        177 N WELLS ST  CHICAGO
# 1     2684099    Restaurant  Risk 2 (Medium)  2741 N MILWAUKEE AVE  CHICAGO
# 2     2163723    Restaurant    Risk 1 (High)     3036 N PULASKI RD  CHICAGO
# 3     2704166    Restaurant  Risk 2 (Medium)        177 N WELLS ST  CHICAGO
# 4     2699239    Restaurant    Risk 1 (High)     1625 N HALSTED ST  CHICAGO
# ..        ...           ...              ...                   ...      ...
# 95    2098744    Restaurant    Risk 1 (High)      1852 N DAMEN AVE  CHICAGO
# 96    2437092    Restaurant    Risk 1 (High)   3200 W LAWRENCE AVE  CHICAGO
# 97      34150    Restaurant  Risk 2 (Medium)     11601 W TOUHY AVE  CHICAGO
# 98    2712646    Restaurant    Risk 1 (High)   3149 W LAWRENCE AVE  CHICAGO
# 99    1878766    Restaurant    Risk 1 (High)     6920 S PULASKI RD  CHICAGO
#
#    State    Zip Inspection Date        Inspection Type             Results  \
# 0     IL  60606       2/13/2020                License                Pass
# 1     IL  60647       2/13/2020                License                Fail
# 2     IL  60641       2/13/2020  Canvass Re-Inspection                Pass
# 3     IL  60606       2/13/2020                License  Pass w/ Conditions
# 4     IL  60614       2/13/2020  License Re-Inspection  Pass w/ Conditions
# ..   ...    ...             ...                    ...                 ...
# 95    IL  60647        2/6/2020  Canvass Re-Inspection                Pass
# 96    IL  60625        2/6/2020   Short Form Complaint                Pass
# 97    IL  60666        2/6/2020                Canvass                Pass
# 98    IL  60625        2/6/2020                License  Pass w/ Conditions
# 99    IL  60629        2/6/2020                Canvass                Pass
#
#                                            Violations   Latitude  Longitude  \
# 0                                                 NaN  41.885257 -87.633770
# 1   5. PROCEDURES FOR RESPONDING TO VOMITING AND D...  41.931042 -87.710406
# 2                                                 NaN  41.936521 -87.727259
# 3   3. MANAGEMENT, FOOD EMPLOYEE AND CONDITIONAL E...  41.885257 -87.633770
# 4   3. MANAGEMENT, FOOD EMPLOYEE AND CONDITIONAL E...  41.911704 -87.648147
# ..                                                ...        ...        ...
# 95                                                NaN  41.915372 -87.677715
# 96  55. PHYSICAL FACILITIES INSTALLED, MAINTAINED ...  41.968561 -87.708536
# 97  36. THERMOMETERS PROVIDED & ACCURATE - Comment...  42.008536 -87.914428
# 98  3. MANAGEMENT, FOOD EMPLOYEE AND CONDITIONAL E...  41.968351 -87.708017
# 99  6. PROPER EATING, TASTING, DRINKING, OR TOBACC...  41.767102 -87.722616
#
#                                     Location
# 0    (41.88525719405359, -87.63376979601067)
# 1    (41.93104159573519, -87.71040591126865)
# 2    (41.93652108441832, -87.72725885229374)
# 3    (41.88525719405359, -87.63376979601067)
# 4     (41.9117043820104, -87.64814711684095)
# ..                                       ...
# 95    (41.91537203392244, -87.6777147461087)
# 96    (41.9685605606405, -87.70853637445603)
# 97  (42.008536400868735, -87.91442843927047)
# 98  (41.968350838801385, -87.70801666203074)
# 99  (41.767101669051904, -87.72261567842712)
#
# [100 rows x 17 columns]

# %% [markdown]
# ### Query for Each Record
# * get star and price ratings

# %%
for index, item in df.iterrows():
    # get Yelp business ID with business match query
    response = yelp_api.business_match_query(
        name=item['DBA Name'].title(),
        address1=item['Address'].title(),
        city=item['City'].title(),
        state=item['State'],
        country='US'
    )
    
    try:
        bus_id = response['businesses'][0]['id']
        df.loc[index,'bus_id'] = bus_id
    except IndexError:
        print(f"{item['DBA Name'].title()} at {item['Address'].title()} is not found in Yelp")
        # move on to next business
        continue
        
    # Use business id to get price and star ratings with business detail query
    response = yelp_api.business_query(id=bus_id)
    try:
        df.loc[index,'cust_rating'] = response['rating']
    except (IndexError, KeyError):
        print(f"{item['DBA Name'].title()} at {item['Address'].title()} has no customer rating")
        
    try:
        df.loc[index,'price_rating'] = response['price'].count('$') # transform from $$ to count
    except (IndexError, KeyError):
        print(f"{item['DBA Name'].title()} at {item['Address'].title()} has no price rating data")
        
    print(f"{item['DBA Name'].title()} data are stored")
# Out:
# 7-Eleven data are stored
# Midlane Esports at 2741 N Milwaukee Ave is not found in Yelp
# El Muchacho Alegre data are stored
# 7-Eleven data are stored
# Pork Chop at 1625 N Halsted St is not found in Yelp
# Midlane Esports at 2741 N Milwaukee Ave is not found in Yelp
# Pho Number 1- Vietnamese Cuisine Llc data are stored
# Royal Nutriton at 2624 W 59Th St is not found in Yelp
# Viva Nutrition Club at 2624 W 59Th St is not found in Yelp
# Bartoli'S Pizzeria at 658 N Ashland Ave is not found in Yelp
# Ajawaah Sweets data are stored
# Stan'S Corner Inc data are stored
# Beefy'S data are stored
# El Rey De La Costa at 3548 W Lawrence Ave has no price rating data
# El Rey De La Costa data are stored
# Captain Hooks data are stored
# Jean'S Cafe & Restaurant data are stored
# Sammy'S Breakfast-Lunch-Dinner at 250 E 103Rd St is not found in Yelp
# El Famous Burrito - Rogers Park data are stored
# Ziggy'S Side Door Pub & Deli at 6158 W 63Rd St has no price rating data
# Ziggy'S Side Door Pub & Deli data are stored
# Dunkin Donuts/Baskin Robbins at 350 E 103Rd St is not found in Yelp
# Sushi Taku at 2283 N Milwaukee Ave is not found in Yelp
# Tamales Lo Mejor De Guerrero data are stored
# Eat Clean Chicago at 4930 S Cicero Ave is not found in Yelp
# Sushi Taku at 2283 N Milwaukee Ave is not found in Yelp
# Subway Sandwich data are stored
# Jimmys Best Mixed Grill at 200 W 103Rd St has no price rating data
# Jimmys Best Mixed Grill data are stored
# Carnitas El Filly at 3537 E 106Th St is not found in Yelp
# Seafood Junction Market at 4515 N Sheridan Rd is not found in Yelp
# Cookies And Carnitas data are stored
# Blowing Smoke Bbq at 131 N Clinton St is not found in Yelp
# Dinos Foods Corp. at 4135 S Archer Ave is not found in Yelp
# Neveria La Flor De Mayo data are stored
# Seashell Restaurant at 6940 S Ashland Ave has no price rating data
# Seashell Restaurant data are stored
# Razpachos data are stored
# Cooked Chicago data are stored
# Great Sea Restaurant data are stored
# Great Buffet at 2531 W Cermak Rd is not found in Yelp
# Mama Luna On Addison Llc data are stored
# Mashwi at 6257 N Mccormick Rd is not found in Yelp
# Hernandez Enterprises Inc at 6983 N Clark St is not found in Yelp
# Mama Luna'S Lounge at 7605-7607 W Addison St has no price rating data
# Mama Luna'S Lounge data are stored
# La Esquina Polar at 5633 W Diversey Ave is not found in Yelp
# Rafa'S Chicken data are stored
# Gulf Fuel & Mini Mart at 5103-5117 W Madison St is not found in Yelp
# La Michoacana De Martha Llc. data are stored
# Mr. Dumpling Inc. at 2485 N Clark St is not found in Yelp
# Fiesta Burger Heaven, Inc. data are stored
# Meson Del Taco Express at 7616 W Belmont Ave has no price rating data
# Meson Del Taco Express data are stored
# Wendy'S Properties, Llc at 4150 S Pulaski Rd is not found in Yelp
# Chavelo'S Tacos, Inc. at 2702 W 47Th St is not found in Yelp
# Subway data are stored
# Rib Palace Llc at 5607 W Corcoran Pl has no price rating data
# Rib Palace Llc data are stored
# Kentucky Fried Chicken at 1914 W 79Th St is not found in Yelp
# Laschet'S Inn data are stored
# Mima'S Taste Of Cuba data are stored
# Laschet'S Inn data are stored
# Dona Tola at 3751 N Southport Ave is not found in Yelp
# Anto Pizza Chicago at 1547 W Jarvis Ave has no price rating data
# Anto Pizza Chicago data are stored
# 6 Degrees data are stored
# Red & White Wines at 1845 N Oakley Ave is not found in Yelp
# Aranda Mexican Restaurant at 6706 W Belmont Ave has no price rating data
# Aranda Mexican Restaurant data are stored
# Denden Restaurant at 6635 N Clark St is not found in Yelp
# Al'S Pizza Chicago data are stored
# Archies at 1228 W Loyola Ave is not found in Yelp
# Margarita'S Healthy Bar at 2850 W 63Rd St is not found in Yelp
# Taqueria El Herradero at 6828 S Pulaski Rd has no price rating data
# Taqueria El Herradero data are stored
# Vip Fit Club at 3426 W Diversey Ave is not found in Yelp
# Bj'S Market & Bakery data are stored
# L C Pho Restaurant data are stored
# El Trompo at 2702 W 47Th St is not found in Yelp
# Lumes Pancake House data are stored
# Wang Happy Garden data are stored
# Nonno Pino data are stored
# Lotus Garden at 7254 W Touhy Ave has no price rating data
# Lotus Garden data are stored
# Jojo One Stop at 2423 W 63Rd St is not found in Yelp
# Vip Nutrition at 3426 W Diversey Ave is not found in Yelp
# Beans & Bagel data are stored
# Doughboy'S Chicago at 352 E 71St St is not found in Yelp
# Blowing Smoke Bbq at 131 N Clinton St is not found in Yelp
# Alvo Corporation at 3216 W Lawrence Ave is not found in Yelp
# Potbelly Sandwich Works data are stored
# Neveria El Sabor De Mexico data are stored
# Tony'S Kitchen #2 Inc. data are stored
# Kentucky Fried Chicken at 7508 S Lafayette Ave is not found in Yelp
# Cipriani'S Pizza data are stored
# Velvet Taco data are stored
# Bartoli'S Pizzeria at 658 N Ashland Ave is not found in Yelp
# Tezcal Restaurant at 4305 N Kedzie Ave has no price rating data
# Tezcal Restaurant data are stored
# Moonlight Vulture data are stored
# Mario'S Table data are stored
# Bulldog Ale House data are stored
# Thai Pastry Restaurant data are stored
# Grace African Restaurant data are stored
# Intelligentsia at 11601 W Touhy Ave is not found in Yelp
# Elliott'S Seafood And Chop House Grill data are stored
# Sarpino'S Pizzeria data are stored
# Brazilian Bowl Fresh Grill data are stored
# Host International Inc at 11601 W Touhy Ave is not found in Yelp
# El Fogon De Elena Restaurant at 3149 W Lawrence Ave is not found in Yelp
# El Campestre #2 data are stored

# %%
df = df[['DBA Name', 'License #', 'bus_id', 'cust_rating', 'price_rating']]
df
# Out:
#                         DBA Name  License #                  bus_id  \
# 0                       7-ELEVEN    2704169  eityapX-OgxF6rjjJ0XmKQ
# 1                MIDLANE ESPORTS    2684099                     NaN
# 2             EL MUCHACHO ALEGRE    2163723  nw3gqyr5xtZfUDwlnv0vtg
# 3                       7-ELEVEN    2704166  eityapX-OgxF6rjjJ0XmKQ
# 4                      PORK CHOP    2699239                     NaN
# ..                           ...        ...                     ...
# 95            SARPINO'S PIZZERIA    2098744  Xe8rZcPu0YpV2aEF4YsOhQ
# 96    BRAZILIAN BOWL FRESH GRILL    2437092  _-toZK3WpdvKpXYjT8wTCg
# 97        HOST INTERNATIONAL INC      34150                     NaN
# 98  EL FOGON DE ELENA RESTAURANT    2712646                     NaN
# 99               EL CAMPESTRE #2    1878766  m19yqoa23qI9omszFHPLcQ
#
#     cust_rating  price_rating
# 0           3.0           1.0
# 1           NaN           NaN
# 2           4.0           1.0
# 3           3.0           1.0
# 4           NaN           NaN
# ..          ...           ...
# 95          2.0           2.0
# 96          4.0           2.0
# 97          NaN           NaN
# 98          NaN           NaN
# 99          3.5           1.0
#
# [100 rows x 5 columns]

# %%
df.to_csv('../Resources/TestData_Yelp_queried.csv', index=False)
